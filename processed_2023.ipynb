# %%
import pandas as pd
import json
import re
import matplotlib.pyplot as plt
import os
#from tabulate import tabulate
#from elasticsearch import Elasticsearch
from IPython.display import display
with open(r'/Org_data.json',encoding='utf-8') as p:
    Org_data = json.load(p)
with open(r'/data_2023.json',encoding='utf-8') as f:
    data_2023 = json.load(f)


# Use pd.json_normalize to convert the JSON to a DataFrame
df_org = pd.json_normalize(Org_data)
#df = pd.json_normalize(data)
df_23 = pd.json_normalize(data_2023)

#print(df_23.head())
#print(df_23.info())
#print(df_23.isnull().sum())
#for col in df_23.columns:
   # print(col)

#print(df_23.columns)

#df_23.columns = ['Title', 'Slug', 'Year', 'Organization', 'Description', 'Goal', 'Ranking', 'Progression', 'Mission Statement', 'End Goal', 'Quota', 'Support Statement', 'Project', 'Impact', 'Collaborations']
df_23.columns = ['Title', 'Slug', 'Year', 'Organization', 'Description', 'Goal', 'Ranking',
                 'Issue Understanding','Stage of Innovation', 'Project Description',
                   'Impact on LA', 'Working Areas in LA',  'Evidence of Success',
                   'Primary Issue Area', 'People Impacted', 'Collaborations']

df_org.columns = ['Slug', 'Status', 'Website', 'Instagram', 'Twitter', 'FaceBook', 'Newsletter', 'Title', 'IRS Standing', 'Zipcode', 'Volunteer', 'Summary', 'Category']
df_23 = df_23.drop(['Ranking'], axis=1)
# Swap the values between 'Impact on LA' and 'Working Areas in LA'
#df_23['Impact on LA'], df_23['Working Areas in LA'] = df_23['Working Areas in LA'], df_23['Impact on LA']



#df_23 = df_23.fillna('Working Individually')
df_23['Collaborations'].fillna('Working Individually', inplace=True)
df_org = df_org.fillna('N/A')
df_23['People Impacted'].fillna('Not Applicable', inplace=True) #Missing 2 values for this category

print(df_23.info())


def extract_direct_impact(text):
    match = re.search(r'Direct Impact: ([\d,]+\.?\d*)', text)
    if match:
        return float(match.group(1).replace(',', ''))  # Remove commas and convert to float
    return None

df_23['People Impacted'] = df_23['People Impacted'].apply(extract_direct_impact)
df_org = df_org.drop_duplicates(subset='Title')
final_List= df_23.merge(df_org , left_on='Organization', right_on= 'Title', how='inner')
final_List = final_List.drop(['Slug_y', 'Title_y'],axis = 1)
final_List = final_List.fillna(0)

#print(df_23.head(10))
#print(df_23.describe())
print(df_23[['Stage of Innovation', 'Issue Understanding']].head(10))
#print(tabulate(df_23.head(10), headers='keys', tablefmt='fancy_grid'))

#print(df_23[['Impact on LA', 'Working Areas in LA']].head())

df_23.to_csv('output_data_23.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612 entries, 0 to 611
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                612 non-null    object
#  1   Slug                 612 non-null    object
#  2   Year                 612 non-null    object
#  3   Organization         612 non-null    object
#  4   Description          612 non-null    object
#  5   Goal                 612 non-null    object
#  6   Issue Understanding  612 non-null    object
#  7   Stage of Innovation  612 non-null    object
#  8   Project Description  612 non-null    object
#  9   Impact on LA         612 non-null    object
#  10  Working Areas in LA  612 non-null    object
#  11  Evidence of Success  612 non-null    object
#  12  Primary Issue Area   612 non-null    object
#  13  People Impacted      612 non-null    object
#  14  Collaborations       612 non-null    object
# dtypes: object(15)
# memory usage: 71.8+ KB
# None
#                                Stage of Innovation  \
# 0  Expand existing project, program, or initiative
# 1  Expand existing project, program, or initiative
# 2     Pilot or new project, program, or initiative
# 3  Expand existing project, program, or initiative
# 4  Expand existing project, program, or initiative
# 5  Expand existing project, program, or initiative
# 6  Expand existing project, program, or initiative
# 7  Expand existing project, program, or initiative
# 8  Expand existing project, program, or initiative
# 9  Expand existing project, program, or initiative
#
#                                  Issue Understanding
# 0                               K-12 STEAM Education
# 1                               K-12 STEAM Education
# 2  Opportunities for People Who Have Been Incarce...
# 3                           Housing and Homelessness
# 4                                   Community Safety
# 5  Youth Economic Advancement (sponsored by the C...
# 6                                  Income Inequality
# 7                           Housing and Homelessness
# 8                               K-12 STEAM Education
# 9  Opportunities for People Who Have Been Incarce...
# /var/folders/68/m3bsdwfj3db_1xm6q6rc522c0000gn/T/ipykernel_31308/605198591.py:42: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_23['Collaborations'].fillna('Working Individually', inplace=True)
# /var/folders/68/m3bsdwfj3db_1xm6q6rc522c0000gn/T/ipykernel_31308/605198591.py:44: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_23['People Impacted'].fillna('Not Applicable', inplace=True) #Missing 2 values for this category
